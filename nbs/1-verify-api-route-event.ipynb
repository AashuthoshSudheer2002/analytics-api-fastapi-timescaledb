# %%
import requests

# %%
path = '/api/events/'
response = requests.get(f"http://localhost:8802{path}")
print(response.ok)
# Out:
# False

# %%
path = '/2'
response = requests.get(f"http://localhost:8802{path}")
print(response.ok)
# Out:
# False
